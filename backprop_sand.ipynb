# %%
import torch, math
import torch.optim as optim
x = torch.tensor([4.5], requires_grad = True)
#y = x**2
#print(x,y)
optimizer = optim.SGD([x],lr = 0.1)#,lr=0.01, momentum=0.9)
for i in range(20):
    optimizer.zero_grad()
    y = torch.square(x)
    y.backward()
    print(x,y)
    optimizer.step()
# Out:
# tensor([4.5000], requires_grad=True) tensor([20.2500], grad_fn=<PowBackward0>)
# tensor([3.6000], requires_grad=True) tensor([12.9600], grad_fn=<PowBackward0>)
# tensor([2.8800], requires_grad=True) tensor([8.2944], grad_fn=<PowBackward0>)
# tensor([2.3040], requires_grad=True) tensor([5.3084], grad_fn=<PowBackward0>)
# tensor([1.8432], requires_grad=True) tensor([3.3974], grad_fn=<PowBackward0>)
# tensor([1.4746], requires_grad=True) tensor([2.1743], grad_fn=<PowBackward0>)
# tensor([1.1796], requires_grad=True) tensor([1.3916], grad_fn=<PowBackward0>)
# tensor([0.9437], requires_grad=True) tensor([0.8906], grad_fn=<PowBackward0>)
# tensor([0.7550], requires_grad=True) tensor([0.5700], grad_fn=<PowBackward0>)
# tensor([0.6040], requires_grad=True) tensor([0.3648], grad_fn=<PowBackward0>)
# tensor([0.4832], requires_grad=True) tensor([0.2335], grad_fn=<PowBackward0>)
# tensor([0.3865], requires_grad=True) tensor([0.1494], grad_fn=<PowBackward0>)
# tensor([0.3092], requires_grad=True) tensor([0.0956], grad_fn=<PowBackward0>)
# tensor([0.2474], requires_grad=True) tensor([0.0612], grad_fn=<PowBackward0>)
# tensor([0.1979], requires_grad=True) tensor([0.0392], grad_fn=<PowBackward0>)
# tensor([0.1583], requires_grad=True) tensor([0.0251], grad_fn=<PowBackward0>)
# tensor([0.1267], requires_grad=True) tensor([0.0160], grad_fn=<PowBackward0>)
# tensor([0.1013], requires_grad=True) tensor([0.0103], grad_fn=<PowBackward0>)
# tensor([0.0811], requires_grad=True) tensor([0.0066], grad_fn=<PowBackward0>)
# tensor([0.0649], requires_grad=True) tensor([0.0042], grad_fn=<PowBackward0>)

# %%
# initial coord
xy = torch.randn(2,requires_grad=True)*10
# grid 
x_coord = torch.linspace(-5.12,5.12,100)#.reshape(-1,1)
y_coord = torch.linspace(-5.12,5.12,100)#.reshape(-1,1)
x_mesh,y_mesh = torch.meshgrid(x_coord, y_coord, indexing='ij')
xy_mesh_stack = torch.stack((x_mesh,y_mesh))
print(xy_mesh_stack.shape)
# target function to find optimum/minimum
A,n,PI = 10,2,torch.tensor(math.pi)
f = lambda coord: A*n+torch.sum(torch.square(coord)-A*torch.cos(2*PI*coord),dim=0)

print(f(xy_mesh_stack).shape)
print(torch.min(f(xy_mesh_stack)))

import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator
import numpy as np

fig, ax = plt.subplots(subplot_kw={"projection": "3d"},figsize=(10,10))
surf = ax.plot_surface(x_mesh, y_mesh, f(xy_mesh_stack), cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)
plt.show()
# Out:
# torch.Size([2, 100, 100])
# torch.Size([100, 100])
# tensor(1.0520)

# %%
deltaX = (max(x_coord) - min(x_coord))/10
deltaY = (max(y_coord) - min(y_coord))/10
xmin = min(x_coord) - deltaX
xmax = max(x_coord) + deltaX
ymin = min(y_coord) - deltaY
ymax = max(y_coord) + deltaY

fig = plt.figure(figsize=(8,8))
ax = fig.gca()
ax.set_xlim(xmin, xmax)
ax.set_ylim(ymin, ymax)
cfset = ax.contourf(x_mesh, y_mesh, f(xy_mesh_stack), cmap='coolwarm')
#ax.imshow(np.rot90(f), cmap='coolwarm', extent=[xmin, xmax, ymin, ymax])
#cset = ax.contour(x_mesh, y_mesh, f(xy_mesh_stack), colors='k')
#ax.clabel(cset, inline=1, fontsize=10)
ax.set_xlabel('X')
ax.set_ylabel('Y')
plt.title('2D plot')
# Out:
# Text(0.5, 1.0, '2D plot')

# %%
import torch, math
import torch.optim as optim
#x = torch.randn(2, requires_grad = True)
x = torch.tensor([1.1,1.1],requires_grad=True)
#y = x**2
#print(x,y)
optimizer = optim.SGD([x],lr = 0.01, momentum=0.3)
A,n,PI = 10,2,torch.tensor(math.pi)
for i in range(100):
    optimizer.zero_grad()
    #y = torch.square(x)
    y = A*n+torch.sum(torch.square(x)-A*torch.cos(2*PI*x),dim=0)
    y.backward()
    print(x,y)
    optimizer.step()
# Out:
# tensor([1.1000, 1.1000], requires_grad=True) tensor(6.2397, grad_fn=<AddBackward0>)
# tensor([0.7087, 0.7087], requires_grad=True) tensor(26.1383, grad_fn=<AddBackward0>)
# tensor([1.1844, 1.1844], requires_grad=True) tensor(14.7911, grad_fn=<AddBackward0>)
# tensor([0.7277, 0.7277], requires_grad=True) tensor(23.8479, grad_fn=<AddBackward0>)
# tensor([1.1984, 1.1984], requires_grad=True) tensor(16.4971, grad_fn=<AddBackward0>)
# tensor([0.7200, 0.7200], requires_grad=True) tensor(24.7788, grad_fn=<AddBackward0>)
# tensor([1.1794, 1.1794], requires_grad=True) tensor(14.1950, grad_fn=<AddBackward0>)
# tensor([0.7261, 0.7261], requires_grad=True) tensor(24.0438, grad_fn=<AddBackward0>)
# tensor([1.1969, 1.1969], requires_grad=True) tensor(16.3138, grad_fn=<AddBackward0>)
# tensor([0.7205, 0.7205], requires_grad=True) tensor(24.7213, grad_fn=<AddBackward0>)
# tensor([1.1808, 1.1808], requires_grad=True) tensor(14.3615, grad_fn=<AddBackward0>)
# tensor([0.7254, 0.7254], requires_grad=True) tensor(24.1293, grad_fn=<AddBackward0>)
# tensor([1.1951, 1.1951], requires_grad=True) tensor(16.0986, grad_fn=<AddBackward0>)
# tensor([0.7208, 0.7208], requires_grad=True) tensor(24.6887, grad_fn=<AddBackward0>)
# tensor([1.1818, 1.1818], requires_grad=True) tensor(14.4880, grad_fn=<AddBackward0>)
# tensor([0.7249, 0.7249], requires_grad=True) tensor(24.1870, grad_fn=<AddBackward0>)
# tensor([1.1939, 1.1939], requires_grad=True) tensor(15.9485, grad_fn=<AddBackward0>)
# tensor([0.7210, 0.7210], requires_grad=True) tensor(24.6614, grad_fn=<AddBackward0>)
# tensor([1.1827, 1.1827], requires_grad=True) tensor(14.5856, grad_fn=<AddBackward0>)
# tensor([0.7246, 0.7246], requires_grad=True) tensor(24.2300, grad_fn=<AddBackward0>)
# tensor([1.1930, 1.1930], requires_grad=True) tensor(15.8357, grad_fn=<AddBackward0>)
# tensor([0.7212, 0.7212], requires_grad=True) tensor(24.6382, grad_fn=<AddBackward0>)
# tensor([1.1833, 1.1833], requires_grad=True) tensor(14.6643, grad_fn=<AddBackward0>)
# tensor([0.7243, 0.7243], requires_grad=True) tensor(24.2636, grad_fn=<AddBackward0>)
# tensor([1.1923, 1.1923], requires_grad=True) tensor(15.7466, grad_fn=<AddBackward0>)
# tensor([0.7214, 0.7214], requires_grad=True) tensor(24.6182, grad_fn=<AddBackward0>)
# tensor([1.1839, 1.1839], requires_grad=True) tensor(14.7296, grad_fn=<AddBackward0>)
# tensor([0.7241, 0.7241], requires_grad=True) tensor(24.2908, grad_fn=<AddBackward0>)
# tensor([1.1917, 1.1917], requires_grad=True) tensor(15.6741, grad_fn=<AddBackward0>)
# tensor([0.7215, 0.7215], requires_grad=True) tensor(24.6010, grad_fn=<AddBackward0>)
# tensor([1.1843, 1.1843], requires_grad=True) tensor(14.7850, grad_fn=<AddBackward0>)
# tensor([0.7239, 0.7239], requires_grad=True) tensor(24.3132, grad_fn=<AddBackward0>)
# tensor([1.1912, 1.1912], requires_grad=True) tensor(15.6136, grad_fn=<AddBackward0>)
# tensor([0.7216, 0.7216], requires_grad=True) tensor(24.5859, grad_fn=<AddBackward0>)
# tensor([1.1847, 1.1847], requires_grad=True) tensor(14.8325, grad_fn=<AddBackward0>)
# tensor([0.7237, 0.7237], requires_grad=True) tensor(24.3321, grad_fn=<AddBackward0>)
# tensor([1.1908, 1.1908], requires_grad=True) tensor(15.5625, grad_fn=<AddBackward0>)
# tensor([0.7218, 0.7218], requires_grad=True) tensor(24.5726, grad_fn=<AddBackward0>)
# tensor([1.1851, 1.1851], requires_grad=True) tensor(14.8738, grad_fn=<AddBackward0>)
# tensor([0.7236, 0.7236], requires_grad=True) tensor(24.3482, grad_fn=<AddBackward0>)
# tensor([1.1904, 1.1904], requires_grad=True) tensor(15.5188, grad_fn=<AddBackward0>)
# tensor([0.7219, 0.7219], requires_grad=True) tensor(24.5608, grad_fn=<AddBackward0>)
# tensor([1.1854, 1.1854], requires_grad=True) tensor(14.9098, grad_fn=<AddBackward0>)
# tensor([0.7235, 0.7235], requires_grad=True) tensor(24.3619, grad_fn=<AddBackward0>)
# tensor([1.1901, 1.1901], requires_grad=True) tensor(15.4811, grad_fn=<AddBackward0>)
# tensor([0.7219, 0.7219], requires_grad=True) tensor(24.5504, grad_fn=<AddBackward0>)
# tensor([1.1856, 1.1856], requires_grad=True) tensor(14.9414, grad_fn=<AddBackward0>)
# tensor([0.7234, 0.7234], requires_grad=True) tensor(24.3739, grad_fn=<AddBackward0>)
# tensor([1.1898, 1.1898], requires_grad=True) tensor(15.4483, grad_fn=<AddBackward0>)
# tensor([0.7220, 0.7220], requires_grad=True) tensor(24.5411, grad_fn=<AddBackward0>)
# tensor([1.1859, 1.1859], requires_grad=True) tensor(14.9693, grad_fn=<AddBackward0>)
# tensor([0.7233, 0.7233], requires_grad=True) tensor(24.3843, grad_fn=<AddBackward0>)
# tensor([1.1896, 1.1896], requires_grad=True) tensor(15.4196, grad_fn=<AddBackward0>)
# tensor([0.7221, 0.7221], requires_grad=True) tensor(24.5329, grad_fn=<AddBackward0>)
# tensor([1.1861, 1.1861], requires_grad=True) tensor(14.9940, grad_fn=<AddBackward0>)
# tensor([0.7232, 0.7232], requires_grad=True) tensor(24.3933, grad_fn=<AddBackward0>)
# tensor([1.1894, 1.1894], requires_grad=True) tensor(15.3945, grad_fn=<AddBackward0>)
# tensor([0.7221, 0.7221], requires_grad=True) tensor(24.5256, grad_fn=<AddBackward0>)
# tensor([1.1863, 1.1863], requires_grad=True) tensor(15.0159, grad_fn=<AddBackward0>)
# tensor([0.7232, 0.7232], requires_grad=True) tensor(24.4013, grad_fn=<AddBackward0>)
# tensor([1.1892, 1.1892], requires_grad=True) tensor(15.3723, grad_fn=<AddBackward0>)
# tensor([0.7222, 0.7222], requires_grad=True) tensor(24.5190, grad_fn=<AddBackward0>)
# tensor([1.1864, 1.1864], requires_grad=True) tensor(15.0353, grad_fn=<AddBackward0>)
# tensor([0.7231, 0.7231], requires_grad=True) tensor(24.4083, grad_fn=<AddBackward0>)
# tensor([1.1890, 1.1890], requires_grad=True) tensor(15.3528, grad_fn=<AddBackward0>)
# tensor([0.7222, 0.7222], requires_grad=True) tensor(24.5131, grad_fn=<AddBackward0>)
# tensor([1.1866, 1.1866], requires_grad=True) tensor(15.0526, grad_fn=<AddBackward0>)
# tensor([0.7231, 0.7231], requires_grad=True) tensor(24.4145, grad_fn=<AddBackward0>)
# tensor([1.1889, 1.1889], requires_grad=True) tensor(15.3356, grad_fn=<AddBackward0>)
# tensor([0.7223, 0.7223], requires_grad=True) tensor(24.5079, grad_fn=<AddBackward0>)
# tensor([1.1867, 1.1867], requires_grad=True) tensor(15.0681, grad_fn=<AddBackward0>)
# tensor([0.7230, 0.7230], requires_grad=True) tensor(24.4199, grad_fn=<AddBackward0>)
# tensor([1.1888, 1.1888], requires_grad=True) tensor(15.3203, grad_fn=<AddBackward0>)
# tensor([0.7223, 0.7223], requires_grad=True) tensor(24.5032, grad_fn=<AddBackward0>)
# tensor([1.1868, 1.1868], requires_grad=True) tensor(15.0818, grad_fn=<AddBackward0>)
# tensor([0.7230, 0.7230], requires_grad=True) tensor(24.4247, grad_fn=<AddBackward0>)
# tensor([1.1887, 1.1887], requires_grad=True) tensor(15.3067, grad_fn=<AddBackward0>)
# tensor([0.7224, 0.7224], requires_grad=True) tensor(24.4990, grad_fn=<AddBackward0>)
# tensor([1.1869, 1.1869], requires_grad=True) tensor(15.0941, grad_fn=<AddBackward0>)
# tensor([0.7229, 0.7229], requires_grad=True) tensor(24.4290, grad_fn=<AddBackward0>)
# tensor([1.1886, 1.1886], requires_grad=True) tensor(15.2947, grad_fn=<AddBackward0>)
# tensor([0.7224, 0.7224], requires_grad=True) tensor(24.4953, grad_fn=<AddBackward0>)
# tensor([1.1870, 1.1870], requires_grad=True) tensor(15.1050, grad_fn=<AddBackward0>)
# tensor([0.7229, 0.7229], requires_grad=True) tensor(24.4328, grad_fn=<AddBackward0>)
# tensor([1.1885, 1.1885], requires_grad=True) tensor(15.2840, grad_fn=<AddBackward0>)
# tensor([0.7224, 0.7224], requires_grad=True) tensor(24.4919, grad_fn=<AddBackward0>)
# tensor([1.1871, 1.1871], requires_grad=True) tensor(15.1147, grad_fn=<AddBackward0>)
# tensor([0.7229, 0.7229], requires_grad=True) tensor(24.4362, grad_fn=<AddBackward0>)
# tensor([1.1884, 1.1884], requires_grad=True) tensor(15.2745, grad_fn=<AddBackward0>)
# tensor([0.7224, 0.7224], requires_grad=True) tensor(24.4889, grad_fn=<AddBackward0>)
# tensor([1.1871, 1.1871], requires_grad=True) tensor(15.1235, grad_fn=<AddBackward0>)
# tensor([0.7229, 0.7229], requires_grad=True) tensor(24.4392, grad_fn=<AddBackward0>)
# tensor([1.1883, 1.1883], requires_grad=True) tensor(15.2660, grad_fn=<AddBackward0>)
# tensor([0.7225, 0.7225], requires_grad=True) tensor(24.4862, grad_fn=<AddBackward0>)
# tensor([1.1872, 1.1872], requires_grad=True) tensor(15.1312, grad_fn=<AddBackward0>)
# tensor([0.7228, 0.7228], requires_grad=True) tensor(24.4418, grad_fn=<AddBackward0>)
# tensor([1.1883, 1.1883], requires_grad=True) tensor(15.2585, grad_fn=<AddBackward0>)
# tensor([0.7225, 0.7225], requires_grad=True) tensor(24.4838, grad_fn=<AddBackward0>)
# tensor([1.1873, 1.1873], requires_grad=True) tensor(15.1382, grad_fn=<AddBackward0>)
# tensor([0.7228, 0.7228], requires_grad=True) tensor(24.4442, grad_fn=<AddBackward0>)
