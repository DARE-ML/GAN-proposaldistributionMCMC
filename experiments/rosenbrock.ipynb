# %%
from Code.mcmc_v2 import Rosenbrock
import torch
import matplotlib.pyplot as plt
from matplotlib import cm
x = y = torch.Tensor([x/100 - 10 for x in range(2001)])
#print(x[0:10],x[-10:])
X,Y = torch.meshgrid(x,y)
def rosenbrock2d(x,y):
    return 100*(y-x)**2+(1-x)**2
Z = rosenbrock2d(X,Y)
fig = plt.figure()
ax = fig.gca(projection='3d')
surf = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, 
                      cmap=cm.RdBu,linewidth=0, antialiased=False)
# Out:
# /home/sean/miniconda3/envs/qttrade/lib/python3.9/site-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  /opt/conda/conda-bld/pytorch_1639180507909/work/aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# /tmp/ipykernel_366/3641953976.py:12: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_366/3641953976.py in <module>
#      11 fig = plt.figure()
#      12 ax = fig.gca(projection='3d')
# ---> 13 surf = ax.plot_surface(X, Y, Z, rstride=1, cstride=1,
#      14                       cmap=cm.RdBu,linewidth=0, antialiased=False)
#
# ~/miniconda3/envs/qttrade/lib/python3.9/site-packages/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     410                          else deprecation_addendum,
#     411                 **kwargs)
# --> 412         return func(*inner_args, **inner_kwargs)
#     413
#     414     DECORATORS[wrapper] = decorator
#
# ~/miniconda3/envs/qttrade/lib/python3.9/site-packages/mpl_toolkits/mplot3d/axes3d.py in plot_surface(self, X, Y, Z, norm, vmin, vmax, lightsource, *args, **kwargs)
#    1676         # note that the striding causes some polygons to have more coordinates
#    1677         # than others
# -> 1678         polyc = art3d.Poly3DCollection(polys, *args, **kwargs)
#    1679
#    1680         if fcolors is not None:
#
# ~/miniconda3/envs/qttrade/lib/python3.9/site-packages/mpl_toolkits/mplot3d/art3d.py in __init__(self, verts, zsort, *args, **kwargs)
#     714         and _edgecolors properties.
#     715         """
# --> 716         super().__init__(verts, *args, **kwargs)
#     717         self.set_zsort(zsort)
#     718         self._codes3d = None
#
# ~/miniconda3/envs/qttrade/lib/python3.9/site-packages/matplotlib/collections.py in __init__(self, verts, sizes, closed, **kwargs)
#    1185         super().__init__(**kwargs)
#    1186         self.set_sizes(sizes)
# -> 1187         self.set_verts(verts, closed)
#    1188         self.stale = True
#    1189
#
# ~/miniconda3/envs/qttrade/lib/python3.9/site-packages/mpl_toolkits/mplot3d/art3d.py in set_verts(self, verts, closed)
#     752     def set_verts(self, verts, closed=True):
#     753         """Set 3D vertices."""
# --> 754         self.get_vector(verts)
#     755         # 2D verts will be updated at draw time
#     756         super().set_verts([], False)
#
# ~/miniconda3/envs/qttrade/lib/python3.9/site-packages/mpl_toolkits/mplot3d/art3d.py in get_vector(self, segments3d)
#     741         """Optimize points for projection."""
#     742         if len(segments3d):
# --> 743             xs, ys, zs = np.row_stack(segments3d).T
#     744         else:  # row_stack can't stack zero arrays.
#     745             xs, ys, zs = [], [], []
#
# <__array_function__ internals> in vstack(*args, **kwargs)
#
# ~/miniconda3/envs/qttrade/lib/python3.9/site-packages/numpy/core/shape_base.py in vstack(tup)
#     221
#     222
# --> 223 @array_function_dispatch(_vhstack_dispatcher)
#     224 def vstack(tup):
#     225     """
#
# KeyboardInterrupt:

# %%
import torch
torch.maximum(torch.ones(5,1),torch.zeros(5,1))
# Out:
# tensor([[1.],
#         [1.],
#         [1.],
#         [1.],
#         [1.]])
